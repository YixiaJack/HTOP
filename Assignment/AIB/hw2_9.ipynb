# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn import preprocessing
from ISLP import load_data
from sklearn.preprocessing import StandardScaler

# %%
College= load_data('College')
College.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
College.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
X = College.iloc[:,3:]
X = X.iloc[:,:-1]
y = College['Apps']
X_train,  X_test,  y_train,  y_test  =  train_test_split(X, y, random_state=0)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
np.mean((lr.predict(X_test) - y_test) ** 2)
# Out:
# 2057759.9378684263

# %%
lr.score(X_test, y_test)
# Out:
# 0.7992199408410867

# %%
data_scaler = StandardScaler()

data_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_transformed = data_scaler.transform(X_train)
X_test_transformed = data_scaler.transform(X_test)

ridge_model = RidgeCV(alphas=np.linspace(.01, 100, 1000), cv=10)
ridge_model.fit(X_train_transformed, y_train)

ridge_model.score(X_test_transformed, y_test)
# Out:
# 0.7953746920667286

# %%
np.mean((ridge_model.predict(data_scaler.transform(X_test)) - y_test) ** 2)
# Out:
# 2097169.224389002

# %%
lasso_model = LassoCV(alphas=np.linspace(.01, 100, 1000), cv=10)
lasso_model.fit(X_train_transformed, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-02, 1.10090090e-01, 2.10180180e-01, 3.10270270e-01,
#        4.10360360e-01, 5.10450450e-01, 6.10540541e-01, 7.10630631e-01,
#        8.10720721e-01, 9.10810811e-01, 1.01090090e+00, 1.11099099e+00,
#        1.21108108e+00, 1.31117117e+00, 1.41126126e+00, 1.51135135e+00,
#        1.61144144e+00, 1.71153153e+00, 1.81162162e+00, 1.91171171e+00,
#        2.01180180e+00, 2.11189189e+0...
#        9.76979279e+01, 9.77980180e+01, 9.78981081e+01, 9.79981982e+01,
#        9.80982883e+01, 9.81983784e+01, 9.82984685e+01, 9.83985586e+01,
#        9.84986486e+01, 9.85987387e+01, 9.86988288e+01, 9.87989189e+01,
#        9.88990090e+01, 9.89990991e+01, 9.90991892e+01, 9.91992793e+01,
#        9.92993694e+01, 9.93994595e+01, 9.94995495e+01, 9.95996396e+01,
#        9.96997297e+01, 9.97998198e+01, 9.98999099e+01, 1.00000000e+02]),
#         cv=10)

# %%
np.mean((lasso_model.predict(data_scaler.transform(X_test)) - y_test) ** 2)
# Out:
# 2041784.1544106356

# %%
lasso_model.score(X_test_transformed, y_test)
# Out:
# 0.8007787323642066
